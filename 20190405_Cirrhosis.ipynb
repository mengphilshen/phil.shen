# %% [markdown]
# # Introduction

# %% [markdown]
# # Data Import

# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
Cirrhosis_DS0 = pd.read_csv('/Users/mengphilshen/Dropbox/Project/Data_Challenges/Proj_Cirrhosis/data/cir_mortality.csv')

# %%
# check metadata
Cirrhosis_DS0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86432 entries, 0 to 86431
# Data columns (total 64 columns):
# VISIT_ID2                          86432 non-null int64
# MORTALITY                          86432 non-null int64
# AKI_CATEGORY2                      86432 non-null object
# ARDS                               86432 non-null object
# ABX                                86432 non-null int64
# BETA_BLOCKER                       86432 non-null int64
# CRYST_RES_VOL_CATEGORY             86432 non-null object
# DIURETIC                           86432 non-null int64
# GIDX_BLEEDING                      86432 non-null int64
# GLYCEMIA                           86432 non-null object
# HE                                 86432 non-null int64
# HRS                                86432 non-null int64
# LVP                                86432 non-null int64
# RRT                                86432 non-null int64
# SBP                                86432 non-null int64
# SEPSIS                             86432 non-null int64
# STEROIDS                           86432 non-null int64
# TIME_TO_ALB_CATEGORY_LOS           86432 non-null object
# VENTILATION                        86432 non-null int64
# VASOPRESSOR                        86432 non-null int64
# ADMISSION_TYPE_GROUP               86432 non-null object
# AGE_GROUP                          86432 non-null object
# BED_SIZE                           86432 non-null object
# CENSUS_REGION                      86432 non-null object
# FEMALE                             86432 non-null int64
# INDEX_YEAR                         86432 non-null int64
# PAYER_GROUP                        86432 non-null object
# RACE_GROUP                         86432 non-null object
# TEACHING_FACILITY                  86432 non-null object
# URBAN                              86432 non-null int64
# VISIT_PER_YEAR_GROUP               86432 non-null object
# ELIXHAUSER_INDEX                   86400 non-null float64
# MELD_Na                            83206 non-null float64
# CONGESTIVE_HEART_FAILURE           86400 non-null float64
# VALVULAR_DISEASE                   86400 non-null float64
# PULMONARY_CIRCULATION_DISEASE      86400 non-null float64
# PERIPHERAL_VASCULAR_DISEASE        86400 non-null float64
# HYPERTENSION                       86400 non-null float64
# PARALYSIS                          86400 non-null float64
# OTHER_NEURO_DISORDERS              86400 non-null float64
# CHRONIC_PULMONARY_DISEASE          86400 non-null float64
# DIABETES_wo_COMPLICATION           86400 non-null float64
# DIABETES_w_COMPLICATION            86400 non-null float64
# HYPOTHYROIDISM                     86400 non-null float64
# RENAL_FAILURE                      86400 non-null float64
# LIVER_DISEASE                      86400 non-null float64
# PEPTIC_ULCER_DISEASE_X_BLEEDING    86400 non-null float64
# AIDS                               86400 non-null float64
# LYMPHOMA                           86400 non-null float64
# METASTATIC_CANCER                  86400 non-null float64
# SOLID_TUMOR_wo_METASTASIS          86400 non-null float64
# ARTHRITIS_COLLAGEN_VAS             86400 non-null float64
# COAGULOPATHY                       86400 non-null float64
# OBESITY                            86400 non-null float64
# WEIGHT_LOSS                        86400 non-null float64
# FLUID_ELECTROLYTE_DISORDER         86400 non-null float64
# CHRONIC_BLOOD_LOSS_ANEMIA          86400 non-null float64
# DEFICIENCY_ANEMIAS                 86400 non-null float64
# ALCOHOL_ABUSE                      86400 non-null float64
# DRUG_ABUSE                         86400 non-null float64
# PSYCHOSES                          86400 non-null float64
# DEPRESSION                         86400 non-null float64
# ALCOHOLIC_CIRRHOSIS                86432 non-null int64
# HEPATITIS                          86432 non-null int64
# dtypes: float64(31), int64(20), object(13)
# memory usage: 42.2+ MB

# %%
# set index
Cirrhosis_DS0.set_index(['VISIT_ID2'], inplace = True)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Delete Missing Values

# %%
# check missing values
missing_data = Cirrhosis_DS0.isnull().sum(axis = 0).reset_index()
missing_data.columns = ['variable', 'missing values']
missing_data['missing %'] = missing_data['missing values'] / Cirrhosis_DS0.shape[0] * 100
missing_data.sort_values('missing %').reset_index(drop = True)
# Out:
#                            variable  missing values  missing %
# 0                         MORTALITY               0   0.000000
# 1               ALCOHOLIC_CIRRHOSIS               0   0.000000
# 2              VISIT_PER_YEAR_GROUP               0   0.000000
# 3                             URBAN               0   0.000000
# 4                 TEACHING_FACILITY               0   0.000000
# 5                        RACE_GROUP               0   0.000000
# 6                       PAYER_GROUP               0   0.000000
# 7                        INDEX_YEAR               0   0.000000
# 8                            FEMALE               0   0.000000
# 9                     CENSUS_REGION               0   0.000000
# 10                         BED_SIZE               0   0.000000
# 11                        AGE_GROUP               0   0.000000
# 12             ADMISSION_TYPE_GROUP               0   0.000000
# 13                      VASOPRESSOR               0   0.000000
# 14                      VENTILATION               0   0.000000
# 15         TIME_TO_ALB_CATEGORY_LOS               0   0.000000
# 16                        HEPATITIS               0   0.000000
# 17                           SEPSIS               0   0.000000
# 18                         STEROIDS               0   0.000000
# 19                             ARDS               0   0.000000
# 20                              ABX               0   0.000000
# 21                     BETA_BLOCKER               0   0.000000
# 22           CRYST_RES_VOL_CATEGORY               0   0.000000
# 23                         DIURETIC               0   0.000000
# 24                    AKI_CATEGORY2               0   0.000000
# 25                         GLYCEMIA               0   0.000000
# 26                               HE               0   0.000000
# 27                              HRS               0   0.000000
# 28                              LVP               0   0.000000
# 29                              RRT               0   0.000000
# ..                              ...             ...        ...
# 33           ARTHRITIS_COLLAGEN_VAS              32   0.037023
# 34                     COAGULOPATHY              32   0.037023
# 35                          OBESITY              32   0.037023
# 36                      WEIGHT_LOSS              32   0.037023
# 37               DEFICIENCY_ANEMIAS              32   0.037023
# 38        CHRONIC_BLOOD_LOSS_ANEMIA              32   0.037023
# 39                    ALCOHOL_ABUSE              32   0.037023
# 40                       DRUG_ABUSE              32   0.037023
# 41                        PSYCHOSES              32   0.037023
# 42                METASTATIC_CANCER              32   0.037023
# 43                       DEPRESSION              32   0.037023
# 44       FLUID_ELECTROLYTE_DISORDER              32   0.037023
# 45                         LYMPHOMA              32   0.037023
# 46        CHRONIC_PULMONARY_DISEASE              32   0.037023
# 47  PEPTIC_ULCER_DISEASE_X_BLEEDING              32   0.037023
# 48                    LIVER_DISEASE              32   0.037023
# 49                    RENAL_FAILURE              32   0.037023
# 50                   HYPOTHYROIDISM              32   0.037023
# 51          DIABETES_w_COMPLICATION              32   0.037023
# 52         DIABETES_wo_COMPLICATION              32   0.037023
# 53            OTHER_NEURO_DISORDERS              32   0.037023
# 54                        PARALYSIS              32   0.037023
# 55                     HYPERTENSION              32   0.037023
# 56      PERIPHERAL_VASCULAR_DISEASE              32   0.037023
# 57    PULMONARY_CIRCULATION_DISEASE              32   0.037023
# 58                 VALVULAR_DISEASE              32   0.037023
# 59         CONGESTIVE_HEART_FAILURE              32   0.037023
# 60                 ELIXHAUSER_INDEX              32   0.037023
# 61                             AIDS              32   0.037023
# 62                          MELD_Na            3226   3.732414
#
# [63 rows x 3 columns]

# %%
# delete missing values
Cirrhosis_DS1 = Cirrhosis_DS0.dropna()
Cirrhosis_DS1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83179 entries, 326305398 to 283396498
# Data columns (total 63 columns):
# MORTALITY                          83179 non-null int64
# AKI_CATEGORY2                      83179 non-null object
# ARDS                               83179 non-null object
# ABX                                83179 non-null int64
# BETA_BLOCKER                       83179 non-null int64
# CRYST_RES_VOL_CATEGORY             83179 non-null object
# DIURETIC                           83179 non-null int64
# GIDX_BLEEDING                      83179 non-null int64
# GLYCEMIA                           83179 non-null object
# HE                                 83179 non-null int64
# HRS                                83179 non-null int64
# LVP                                83179 non-null int64
# RRT                                83179 non-null int64
# SBP                                83179 non-null int64
# SEPSIS                             83179 non-null int64
# STEROIDS                           83179 non-null int64
# TIME_TO_ALB_CATEGORY_LOS           83179 non-null object
# VENTILATION                        83179 non-null int64
# VASOPRESSOR                        83179 non-null int64
# ADMISSION_TYPE_GROUP               83179 non-null object
# AGE_GROUP                          83179 non-null object
# BED_SIZE                           83179 non-null object
# CENSUS_REGION                      83179 non-null object
# FEMALE                             83179 non-null int64
# INDEX_YEAR                         83179 non-null int64
# PAYER_GROUP                        83179 non-null object
# RACE_GROUP                         83179 non-null object
# TEACHING_FACILITY                  83179 non-null object
# URBAN                              83179 non-null int64
# VISIT_PER_YEAR_GROUP               83179 non-null object
# ELIXHAUSER_INDEX                   83179 non-null float64
# MELD_Na                            83179 non-null float64
# CONGESTIVE_HEART_FAILURE           83179 non-null float64
# VALVULAR_DISEASE                   83179 non-null float64
# PULMONARY_CIRCULATION_DISEASE      83179 non-null float64
# PERIPHERAL_VASCULAR_DISEASE        83179 non-null float64
# HYPERTENSION                       83179 non-null float64
# PARALYSIS                          83179 non-null float64
# OTHER_NEURO_DISORDERS              83179 non-null float64
# CHRONIC_PULMONARY_DISEASE          83179 non-null float64
# DIABETES_wo_COMPLICATION           83179 non-null float64
# DIABETES_w_COMPLICATION            83179 non-null float64
# HYPOTHYROIDISM                     83179 non-null float64
# RENAL_FAILURE                      83179 non-null float64
# LIVER_DISEASE                      83179 non-null float64
# PEPTIC_ULCER_DISEASE_X_BLEEDING    83179 non-null float64
# AIDS                               83179 non-null float64
# LYMPHOMA                           83179 non-null float64
# METASTATIC_CANCER                  83179 non-null float64
# SOLID_TUMOR_wo_METASTASIS          83179 non-null float64
# ARTHRITIS_COLLAGEN_VAS             83179 non-null float64
# COAGULOPATHY                       83179 non-null float64
# OBESITY                            83179 non-null float64
# WEIGHT_LOSS                        83179 non-null float64
# FLUID_ELECTROLYTE_DISORDER         83179 non-null float64
# CHRONIC_BLOOD_LOSS_ANEMIA          83179 non-null float64
# DEFICIENCY_ANEMIAS                 83179 non-null float64
# ALCOHOL_ABUSE                      83179 non-null float64
# DRUG_ABUSE                         83179 non-null float64
# PSYCHOSES                          83179 non-null float64
# DEPRESSION                         83179 non-null float64
# ALCOHOLIC_CIRRHOSIS                83179 non-null int64
# HEPATITIS                          83179 non-null int64
# dtypes: float64(31), int64(19), object(13)
# memory usage: 40.6+ MB

# %% [markdown]
# ## Encode Categorical Features

# %%
# encode categorical features
Cirrhosis_DS2 = pd.get_dummies(Cirrhosis_DS1)
Cirrhosis_DS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83179 entries, 326305398 to 283396498
# Columns: 104 entries, MORTALITY to VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q4
# dtypes: float64(31), int64(19), uint8(54)
# memory usage: 36.6 MB

# %%
# drop one level to avoid collinearity
variables_to_drop = ['AKI_CATEGORY2_NONE', 'ARDS_NONE', 'CRYST_RES_VOL_CATEGORY_>1250', 
                     'GLYCEMIA_NEITHER', 'TIME_TO_ALB_CATEGORY_LOS_NONE', 'ADMISSION_TYPE_GROUP_Emergency', 
                     'AGE_GROUP_18-29', 'BED_SIZE_0-99', 'CENSUS_REGION_South', 
                     'PAYER_GROUP_Commercial', 'RACE_GROUP_Caucasian', 'TEACHING_FACILITY_No', 
                     'VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q4']
Cirrhosis_DS3 = Cirrhosis_DS2.drop(variables_to_drop, axis = 1)
Cirrhosis_DS3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83179 entries, 326305398 to 283396498
# Data columns (total 91 columns):
# MORTALITY                                 83179 non-null int64
# ABX                                       83179 non-null int64
# BETA_BLOCKER                              83179 non-null int64
# DIURETIC                                  83179 non-null int64
# GIDX_BLEEDING                             83179 non-null int64
# HE                                        83179 non-null int64
# HRS                                       83179 non-null int64
# LVP                                       83179 non-null int64
# RRT                                       83179 non-null int64
# SBP                                       83179 non-null int64
# SEPSIS                                    83179 non-null int64
# STEROIDS                                  83179 non-null int64
# VENTILATION                               83179 non-null int64
# VASOPRESSOR                               83179 non-null int64
# FEMALE                                    83179 non-null int64
# INDEX_YEAR                                83179 non-null int64
# URBAN                                     83179 non-null int64
# ELIXHAUSER_INDEX                          83179 non-null float64
# MELD_Na                                   83179 non-null float64
# CONGESTIVE_HEART_FAILURE                  83179 non-null float64
# VALVULAR_DISEASE                          83179 non-null float64
# PULMONARY_CIRCULATION_DISEASE             83179 non-null float64
# PERIPHERAL_VASCULAR_DISEASE               83179 non-null float64
# HYPERTENSION                              83179 non-null float64
# PARALYSIS                                 83179 non-null float64
# OTHER_NEURO_DISORDERS                     83179 non-null float64
# CHRONIC_PULMONARY_DISEASE                 83179 non-null float64
# DIABETES_wo_COMPLICATION                  83179 non-null float64
# DIABETES_w_COMPLICATION                   83179 non-null float64
# HYPOTHYROIDISM                            83179 non-null float64
# RENAL_FAILURE                             83179 non-null float64
# LIVER_DISEASE                             83179 non-null float64
# PEPTIC_ULCER_DISEASE_X_BLEEDING           83179 non-null float64
# AIDS                                      83179 non-null float64
# LYMPHOMA                                  83179 non-null float64
# METASTATIC_CANCER                         83179 non-null float64
# SOLID_TUMOR_wo_METASTASIS                 83179 non-null float64
# ARTHRITIS_COLLAGEN_VAS                    83179 non-null float64
# COAGULOPATHY                              83179 non-null float64
# OBESITY                                   83179 non-null float64
# WEIGHT_LOSS                               83179 non-null float64
# FLUID_ELECTROLYTE_DISORDER                83179 non-null float64
# CHRONIC_BLOOD_LOSS_ANEMIA                 83179 non-null float64
# DEFICIENCY_ANEMIAS                        83179 non-null float64
# ALCOHOL_ABUSE                             83179 non-null float64
# DRUG_ABUSE                                83179 non-null float64
# PSYCHOSES                                 83179 non-null float64
# DEPRESSION                                83179 non-null float64
# ALCOHOLIC_CIRRHOSIS                       83179 non-null int64
# HEPATITIS                                 83179 non-null int64
# AKI_CATEGORY2_MILD                        83179 non-null uint8
# AKI_CATEGORY2_SEVERE                      83179 non-null uint8
# ARDS_MILD ARDS                            83179 non-null uint8
# ARDS_MODERATE ARDS                        83179 non-null uint8
# ARDS_SEVERE ARDS                          83179 non-null uint8
# CRYST_RES_VOL_CATEGORY_(0, 500]           83179 non-null uint8
# CRYST_RES_VOL_CATEGORY_(500, 1250]        83179 non-null uint8
# CRYST_RES_VOL_CATEGORY_NONE               83179 non-null uint8
# GLYCEMIA_BOTH                             83179 non-null uint8
# GLYCEMIA_HYPERGLYCEMIA                    83179 non-null uint8
# GLYCEMIA_HYPOGLYCEMIA                     83179 non-null uint8
# TIME_TO_ALB_CATEGORY_LOS_(0, 24]          83179 non-null uint8
# TIME_TO_ALB_CATEGORY_LOS_>24              83179 non-null uint8
# ADMISSION_TYPE_GROUP_Elective             83179 non-null uint8
# ADMISSION_TYPE_GROUP_Urgent               83179 non-null uint8
# AGE_GROUP_30-49                           83179 non-null uint8
# AGE_GROUP_50-64                           83179 non-null uint8
# AGE_GROUP_65+                             83179 non-null uint8
# BED_SIZE_100-199                          83179 non-null uint8
# BED_SIZE_200-299                          83179 non-null uint8
# BED_SIZE_300-499                          83179 non-null uint8
# BED_SIZE_500+                             83179 non-null uint8
# CENSUS_REGION_Midwest                     83179 non-null uint8
# CENSUS_REGION_Northeast                   83179 non-null uint8
# CENSUS_REGION_West                        83179 non-null uint8
# PAYER_GROUP_Medicaid                      83179 non-null uint8
# PAYER_GROUP_Medicare                      83179 non-null uint8
# PAYER_GROUP_Null or Exclude               83179 non-null uint8
# PAYER_GROUP_Oth. Govt. or Mil.            83179 non-null uint8
# PAYER_GROUP_Oth. NGO or Work Comp.        83179 non-null uint8
# PAYER_GROUP_Self                          83179 non-null uint8
# RACE_GROUP_African American               83179 non-null uint8
# RACE_GROUP_Asian/Pacific Islander         83179 non-null uint8
# RACE_GROUP_Hispanic                       83179 non-null uint8
# RACE_GROUP_Not Specified                  83179 non-null uint8
# RACE_GROUP_Other                          83179 non-null uint8
# TEACHING_FACILITY_Not Specified           83179 non-null uint8
# TEACHING_FACILITY_Yes                     83179 non-null uint8
# VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q1    83179 non-null uint8
# VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q2    83179 non-null uint8
# VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q3    83179 non-null uint8
# dtypes: float64(31), int64(19), uint8(41)
# memory usage: 35.6 MB

# %%
# check table
Cirrhosis_DS3.head()
# Out:
#            MORTALITY  ABX  BETA_BLOCKER  DIURETIC  GIDX_BLEEDING  HE  HRS  \
# VISIT_ID2
# 326305398          0    1             0         1              0   0    0
# 326305419          0    1             0         0              0   0    0
# 340607531          0    0             0         1              0   0    0
# 340607536          0    0             0         0              1   0    0
# 269544789          1    1             0         1              0   0    0
#
#            LVP  RRT  SBP                   ...                    \
# VISIT_ID2                                  ...
# 326305398    0    0    0                   ...
# 326305419    0    0    0                   ...
# 340607531    1    0    0                   ...
# 340607536    0    0    0                   ...
# 269544789    0    1    0                   ...
#
#            RACE_GROUP_African American  RACE_GROUP_Asian/Pacific Islander  \
# VISIT_ID2
# 326305398                            0                                  0
# 326305419                            0                                  0
# 340607531                            0                                  0
# 340607536                            0                                  0
# 269544789                            0                                  0
#
#            RACE_GROUP_Hispanic  RACE_GROUP_Not Specified  RACE_GROUP_Other  \
# VISIT_ID2
# 326305398                    0                         0                 0
# 326305419                    0                         0                 0
# 340607531                    0                         0                 0
# 340607536                    0                         0                 0
# 269544789                    0                         0                 0
#
#            TEACHING_FACILITY_Not Specified  TEACHING_FACILITY_Yes  \
# VISIT_ID2
# 326305398                                1                      0
# 326305419                                1                      0
# 340607531                                1                      0
# 340607536                                1                      0
# 269544789                                1                      0
#
#            VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q1  \
# VISIT_ID2
# 326305398                                       1
# 326305419                                       1
# 340607531                                       0
# 340607536                                       0
# 269544789                                       0
#
#            VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q2  \
# VISIT_ID2
# 326305398                                       0
# 326305419                                       0
# 340607531                                       1
# 340607536                                       1
# 269544789                                       1
#
#            VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q3
# VISIT_ID2
# 326305398                                       0
# 326305419                                       0
# 340607531                                       0
# 340607536                                       0
# 269544789                                       0
#
# [5 rows x 91 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Seperate Features and Targets

# %%
# create the target vector
y = Cirrhosis_DS3.iloc[:, Cirrhosis_DS3.columns == 'MORTALITY']
y['MORTALITY'].value_counts()
# Out:
# 0    74275
# 1     8904
# Name: MORTALITY, dtype: int64

# %%
# create the features matrix
X = Cirrhosis_DS3.iloc[:, Cirrhosis_DS3.columns != 'MORTALITY']
X.describe()
# Out:
#                 ABX  BETA_BLOCKER      DIURETIC  GIDX_BLEEDING            HE  \
# count  83179.000000  83179.000000  83179.000000   83179.000000  83179.000000
# mean       0.616382      0.164092      0.440436       0.144964      0.192188
# std        0.486270      0.370361      0.496442       0.352067      0.394022
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        0.000000      0.000000      0.000000       0.000000      0.000000
# 50%        1.000000      0.000000      0.000000       0.000000      0.000000
# 75%        1.000000      0.000000      1.000000       0.000000      0.000000
# max        1.000000      1.000000      1.000000       1.000000      1.000000
#
#                 HRS           LVP           RRT           SBP        SEPSIS  \
# count  83179.000000  83179.000000  83179.000000  83179.000000  83179.000000
# mean       0.045576      0.264526      0.057683      0.035838      0.110785
# std        0.208566      0.441083      0.233144      0.185888      0.313868
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                         ...                    RACE_GROUP_African American  \
# count                   ...                                   83179.000000
# mean                    ...                                       0.138665
# std                     ...                                       0.345598
# min                     ...                                       0.000000
# 25%                     ...                                       0.000000
# 50%                     ...                                       0.000000
# 75%                     ...                                       0.000000
# max                     ...                                       1.000000
#
#        RACE_GROUP_Asian/Pacific Islander  RACE_GROUP_Hispanic  \
# count                       83179.000000         83179.000000
# mean                            0.014306             0.013549
# std                             0.118752             0.115610
# min                             0.000000             0.000000
# 25%                             0.000000             0.000000
# 50%                             0.000000             0.000000
# 75%                             0.000000             0.000000
# max                             1.000000             1.000000
#
#        RACE_GROUP_Not Specified  RACE_GROUP_Other  \
# count              83179.000000      83179.000000
# mean                   0.015304          0.071388
# std                    0.122761          0.257474
# min                    0.000000          0.000000
# 25%                    0.000000          0.000000
# 50%                    0.000000          0.000000
# 75%                    0.000000          0.000000
# max                    1.000000          1.000000
#
#        TEACHING_FACILITY_Not Specified  TEACHING_FACILITY_Yes  \
# count                     83179.000000           83179.000000
# mean                          0.170812               0.675435
# std                           0.376347               0.468215
# min                           0.000000               0.000000
# 25%                           0.000000               0.000000
# 50%                           0.000000               1.000000
# 75%                           0.000000               1.000000
# max                           1.000000               1.000000
#
#        VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q1  \
# count                            83179.000000
# mean                                 0.266089
# std                                  0.441914
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  1.000000
# max                                  1.000000
#
#        VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q2  \
# count                            83179.000000
# mean                                 0.244665
# std                                  0.429891
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        VISIT_PER_YEAR_GROUP_VISIT_PER_YEAR_Q3
# count                            83179.000000
# mean                                 0.249907
# std                                  0.432961
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
# [8 rows x 90 columns]

# %% [markdown]
# ## Split Data into Training and Test Sets

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 12345)
print('Training Features Shape:', X_train.shape)
print('Training Lable Shape:', y_train.shape)
print('Test Features Shape:', X_test.shape)
print('Test Lable Shape:', y_test.shape)
# Out:
# Training Features Shape: (58225, 90)
# Training Lable Shape: (58225, 1)
# Test Features Shape: (24954, 90)
# Test Lable Shape: (24954, 1)

# %%
# fit standardizer to training set
standardizer = StandardScaler()
standardizer.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# apply to both training and test sets
X_trian_std = standardizer.transform(X_train)
X_test_std = standardizer.transform(X_test)

# %%
# covert labels to arrays
y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Train Model

# %%
# create a base Logistic model
base_logit = LogisticRegression(class_weight = 'balanced', random_state = 12345)

# %%
# train the model on training data
base_logit.fit(X_trian_std , y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2',
#           random_state=12345, solver='warn', tol=0.0001, verbose=0,
#           warm_start=False)

# %% [markdown]
# ## Predict Test Data

# %%
# predict test data
y_pred_logit = base_logit.predict(X_test_std)
y_pred_prob_logit = base_logit.predict_proba(X_test_std)

# %% [markdown]
# ## Evaulate Performance

# %%
# plot confusion matrix
skplt.metrics.plot_confusion_matrix(y_test, y_pred_logit)
plt.show()

# %%
# extract true_positives, false_positives, true_negatives, false_negatives
cm_matrix = confusion_matrix(y_test, y_pred_logit)
tn, fp, fn, tp = cm_matrix.ravel()
print('True Negatives: ', tn)
print('False Positives: ', fp)
print('False Negatives: ', fn)
print('True Positives: ', tp)
# Out:
# True Negatives:  18727
# False Positives:  3493
# False Negatives:  530
# True Positives:  2204

# %%
# accuracy
accuracy = (tn+tp)/(tp+tn+fp+fn)
print("Accuracy {:0.2f}:".format(accuracy))
# Out:
# Accuracy 0.84:

# %%
# precision
precision = tp/(tp+fp)
print("Precision {:0.2f}:".format(precision))
# Out:
# Precision 0.39:

# %%
# recall
recall = tp /(tp+fn)
print("# Recall {:0.2f}:".format(recall))
# Out:
# # Recall 0.81:

# %%
# f1 score
f1 = (2*precision*recall)/(precision+recall)
print("# F1 Score {:0.2f}:".format(f1))
# Out:
# # F1 Score 0.52:

# %%
# print classification report
print(classification_report(y_test, y_pred_logit))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90     22220
#            1       0.39      0.81      0.52      2734
#
#    micro avg       0.84      0.84      0.84     24954
#    macro avg       0.68      0.82      0.71     24954
# weighted avg       0.91      0.84      0.86     24954

# %%
# plot ROC curves
skplt.metrics.plot_roc_curve(y_test, y_pred_prob_logit, curves = ('each_class'))
plt.show()

# %%
# plot Precision-Recall curve
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_prob_logit, curves = ('each_class'))
plt.show()

# %% [markdown]
# # Random Forests

# %% [markdown]
# ## Train Model

# %%
# create a base Random Forest model
base_rf = RandomForestClassifier(n_estimators = 1000, class_weight = 'balanced', random_state = 12345)

# %%
# train the model on training data
base_rf.fit(X_trian_std , y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=1000, n_jobs=None, oob_score=False,
#             random_state=12345, verbose=0, warm_start=False)

# %% [markdown]
# ## Predict Test Data

# %%
# predict test data
y_pred_rf = base_rf.predict(X_test_std)
y_pred_prob_rf = base_rf.predict_proba(X_test_std)

# %% [markdown]
# ## Evaulate Performance

# %%
# plot confusion matrix
skplt.metrics.plot_confusion_matrix(y_test, y_pred_rf)
plt.show()

# %%
# extract true_positives, false_positives, true_negatives, false_negatives
cm_matrix = confusion_matrix(y_test, y_pred_rf)
tn, fp, fn, tp = cm_matrix.ravel()
print('True Negatives: ', tn)
print('False Positives: ', fp)
print('False Negatives: ', fn)
print('True Positives: ', tp)
# Out:
# True Negatives:  22058
# False Positives:  162
# False Negatives:  2151
# True Positives:  583

# %%
# accuracy
accuracy = (tn+tp)/(tp+tn+fp+fn)
print("Accuracy {:0.2f}:".format(accuracy))
# Out:
# Accuracy 0.91:

# %%
# precision
precision = tp/(tp+fp)
print("Precision {:0.2f}:".format(precision))
# Out:
# Precision 0.78:

# %%
# recall
recall = tp /(tp+fn)
print("# Recall {:0.2f}:".format(recall))
# Out:
# # Recall 0.21:

# %%
# f1 score
f1 = (2*precision*recall)/(precision+recall)
print("# F1 Score {:0.2f}:".format(f1))
# Out:
# # F1 Score 0.34:

# %%
# print classification report
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     22220
#            1       0.78      0.21      0.34      2734
#
#    micro avg       0.91      0.91      0.91     24954
#    macro avg       0.85      0.60      0.64     24954
# weighted avg       0.90      0.91      0.88     24954

# %%
# plot ROC curves
skplt.metrics.plot_roc_curve(y_test, y_pred_prob_rf, curves = ('each_class'))
plt.show()

# %%
# plot Precision-Recall curve
skplt.metrics.plot_precision_recall_curve(y_test, y_pred_prob_rf, curves = ('each_class'))
plt.show()

# %% [markdown]
# ## Examine Variable Importances

# %%
# create a dataframe of feature importances
feature_importances = pd.DataFrame()
feature_importances['feature'] = X.columns
feature_importances['importance'] = base_rf.feature_importances_
feature_importances.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 2 columns):
# feature       90 non-null object
# importance    90 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.5+ KB

# %%
# sort dataframe by feature importances
feature_importances_srt = feature_importances.sort_values(by='importance', ascending = False).reset_index()
feature_importances_srt
# Out:
#     index                             feature  importance
# 0      17                             MELD_Na    0.097317
# 1      12                         VASOPRESSOR    0.074025
# 2       9                              SEPSIS    0.069124
# 3      11                         VENTILATION    0.068264
# 4      16                    ELIXHAUSER_INDEX    0.050279
# 5      49                  AKI_CATEGORY2_MILD    0.036698
# 6      50                AKI_CATEGORY2_SEVERE    0.031124
# 7      14                          INDEX_YEAR    0.026306
# 8      53                    ARDS_SEVERE ARDS    0.022517
# 9      61        TIME_TO_ALB_CATEGORY_LOS_>24    0.019518
# 10     34                   METASTATIC_CANCER    0.012741
# 11     57                       GLYCEMIA_BOTH    0.012178
# 12     66                       AGE_GROUP_65+    0.011286
# 13      5                                 HRS    0.011153
# 14     59               GLYCEMIA_HYPOGLYCEMIA    0.010371
# 15      0                                 ABX    0.009849
# 16     40          FLUID_ELECTROLYTE_DISORDER    0.009809
# 17      4                                  HE    0.009773
# 18     72             CENSUS_REGION_Northeast    0.009291
# 19     39                         WEIGHT_LOSS    0.009236
# 20      2                            DIURETIC    0.009091
# 21     10                            STEROIDS    0.008996
# 22     37                        COAGULOPATHY    0.008992
# 23     13                              FEMALE    0.008643
# 24     42                  DEFICIENCY_ANEMIAS    0.008619
# 25     30                       LIVER_DISEASE    0.008610
# 26     22                        HYPERTENSION    0.008458
# 27     54     CRYST_RES_VOL_CATEGORY_(0, 500]    0.008123
# 28      6                                 LVP    0.008096
# 29     55  CRYST_RES_VOL_CATEGORY_(500, 1250]    0.008025
# ..    ...                                 ...         ...
# 60      7                                 RRT    0.005732
# 61     56         CRYST_RES_VOL_CATEGORY_NONE    0.005666
# 62     76         PAYER_GROUP_Null or Exclude    0.005647
# 63     19                    VALVULAR_DISEASE    0.005598
# 64     80         RACE_GROUP_African American    0.005587
# 65     71               CENSUS_REGION_Midwest    0.005584
# 66     85     TEACHING_FACILITY_Not Specified    0.005179
# 67     20       PULMONARY_CIRCULATION_DISEASE    0.005159
# 68     45                           PSYCHOSES    0.005137
# 69     74                PAYER_GROUP_Medicaid    0.005075
# 70     35           SOLID_TUMOR_wo_METASTASIS    0.005003
# 71     73                  CENSUS_REGION_West    0.004786
# 72     62       ADMISSION_TYPE_GROUP_Elective    0.004741
# 73     67                    BED_SIZE_100-199    0.004555
# 74     44                          DRUG_ABUSE    0.004293
# 75     51                      ARDS_MILD ARDS    0.003538
# 76     41           CHRONIC_BLOOD_LOSS_ANEMIA    0.003505
# 77     84                    RACE_GROUP_Other    0.003442
# 78     23                           PARALYSIS    0.003142
# 79      8                                 SBP    0.003042
# 80     36              ARTHRITIS_COLLAGEN_VAS    0.002746
# 81     79                    PAYER_GROUP_Self    0.002491
# 82     33                            LYMPHOMA    0.002202
# 83     77      PAYER_GROUP_Oth. Govt. or Mil.    0.001934
# 84     83            RACE_GROUP_Not Specified    0.001355
# 85     78  PAYER_GROUP_Oth. NGO or Work Comp.    0.001257
# 86     31     PEPTIC_ULCER_DISEASE_X_BLEEDING    0.001239
# 87     81   RACE_GROUP_Asian/Pacific Islander    0.001222
# 88     32                                AIDS    0.001007
# 89     82                 RACE_GROUP_Hispanic    0.000715
#
# [90 rows x 3 columns]

# %%
# plot Top 20 feature importances
feature_importances_top20 = feature_importances_srt.iloc[0:20, :]
feature_importances_top20.sort_values(by='importance', ascending = True, inplace = True)
feature_importances_top20.plot(x = 'feature', y = 'importance', kind = 'barh', legend = False)
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# # Conclusion
